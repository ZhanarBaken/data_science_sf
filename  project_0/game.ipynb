# %% [markdown]
# # Guess the number

# %%
from game import score_game
from game import optimal_predict
# Out:
# Компьютер угадал число за 6 попыток. Это число 60
# Компьютер угадал число за 7 попыток. Это число 67
# Компьютер угадал число за 2 попыток. Это число 75
# Компьютер угадал число за 7 попыток. Это число 92
# Компьютер угадал число за 7 попыток. Это число 6
# Компьютер угадал число за 7 попыток. Это число 27
# Компьютер угадал число за 4 попыток. Это число 68
# Компьютер угадал число за 6 попыток. Это число 32
# Компьютер угадал число за 7 попыток. Это число 12
# Компьютер угадал число за 5 попыток. Это число 4
# Компьютер угадал число за 7 попыток. Это число 55
# Компьютер угадал число за 6 попыток. Это число 2
# Компьютер угадал число за 6 попыток. Это число 14
# Компьютер угадал число за 6 попыток. Это число 60
# Компьютер угадал число за 6 попыток. Это число 57
# Компьютер угадал число за 6 попыток. Это число 82
# Компьютер угадал число за 7 попыток. Это число 9
# Компьютер угадал число за 7 попыток. Это число 39
# Компьютер угадал число за 6 попыток. Это число 5
# ...

# %% [markdown]
# ## Random guessing less then 20 times

# %%
score_game(optimal_predict)
# Out:
# Компьютер угадал число за 6 попыток. Это число 60
# Компьютер угадал число за 7 попыток. Это число 67
# Компьютер угадал число за 2 попыток. Это число 75
# Компьютер угадал число за 7 попыток. Это число 92
# Компьютер угадал число за 7 попыток. Это число 6
# Компьютер угадал число за 7 попыток. Это число 27
# Компьютер угадал число за 4 попыток. Это число 68
# Компьютер угадал число за 6 попыток. Это число 32
# Компьютер угадал число за 7 попыток. Это число 12
# Компьютер угадал число за 5 попыток. Это число 4
# Компьютер угадал число за 7 попыток. Это число 55
# Компьютер угадал число за 6 попыток. Это число 2
# Компьютер угадал число за 6 попыток. Это число 14
# Компьютер угадал число за 6 попыток. Это число 60
# Компьютер угадал число за 6 попыток. Это число 57
# Компьютер угадал число за 6 попыток. Это число 82
# Компьютер угадал число за 7 попыток. Это число 9
# Компьютер угадал число за 7 попыток. Это число 39
# Компьютер угадал число за 6 попыток. Это число 5
# ...
